# %%
# !pip install transformers[torch]

# %%
from transformers import pipeline
Voice_to_text=pipeline('automatic-speech-recognition',model="openai/whisper-base")
Vts=Voice_to_text('output_audio.wav')
print(Vts)
# Out:
# Device set to use cpu
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:512: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# {'text': " I don't like his library, look messy."}

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-54aa66ea-c14d-4f36-bc30-340add3c0c22" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-54aa66ea-c14d-4f36-bc30-340add3c0c22">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
text_generator=pipeline('text-generation')
generate_Text=[]
for i in range(10):
  text = text_generator(Vts['text'])
  generate_Text.append(text[0])
for idx, txt in enumerate(generate_Text):
    print(f"Generated Text {idx}: {txt}")
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
from transformers import pipeline

Sentiment_analyzer = pipeline("sentiment-analysis")


sentiment_result = []

for i in generate_Text:
    sentiment = Sentiment_analyzer(i['generated_text'])[0]
    sentiment_result.append(sentiment)

for lists in sentiment_result:
  print(lists)

top_priority = sentiment_result[0]

for i in sentiment_result:
  if i['label']=='POSITIVE':
    if i['score'] > top_priority['score']:
      top_priority = i

print("top_priority" , top_priority)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# {'label': 'NEGATIVE', 'score': 0.9797273874282837}
# {'label': 'NEGATIVE', 'score': 0.9996073842048645}
# {'label': 'NEGATIVE', 'score': 0.9940820336341858}
# {'label': 'POSITIVE', 'score': 0.9929563999176025}
# {'label': 'NEGATIVE', 'score': 0.8561599254608154}
# {'label': 'NEGATIVE', 'score': 0.995212197303772}
# {'label': 'POSITIVE', 'score': 0.6825584173202515}
# {'label': 'POSITIVE', 'score': 0.9995843768119812}
# {'label': 'POSITIVE', 'score': 0.9948327541351318}
# {'label': 'NEGATIVE', 'score': 0.9972686767578125}
# top_priority {'label': 'POSITIVE', 'score': 0.9995843768119812}

# %%
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# {'label': 'NEGATIVE', 'score': 0.9797273874282837}
# {'label': 'NEGATIVE', 'score': 0.9996073842048645}
# {'label': 'NEGATIVE', 'score': 0.9940820336341858}
# {'label': 'POSITIVE', 'score': 0.9929563999176025}
# {'label': 'NEGATIVE', 'score': 0.8561599254608154}
# {'label': 'NEGATIVE', 'score': 0.995212197303772}
# {'label': 'POSITIVE', 'score': 0.6825584173202515}
# {'label': 'POSITIVE', 'score': 0.9995843768119812}
# {'label': 'POSITIVE', 'score': 0.9948327541351318}
# {'label': 'NEGATIVE', 'score': 0.9972686767578125}
# top_priority {'label': 'NEGATIVE', 'score': 0.9996073842048645}
